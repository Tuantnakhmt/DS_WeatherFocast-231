# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('weather_hanoi.csv')
data.head()
# Out:
#    Unnamed: 0      lat       lon       name      timestamp_local  \
# 0           0  21.0285  105.8542  Hoàn Kiếm  2023-11-11T07:00:00
# 1           1  21.0285  105.8542  Hoàn Kiếm  2023-11-11T08:00:00
# 2           2  21.0285  105.8542  Hoàn Kiếm  2023-11-11T09:00:00
# 3           3  21.0285  105.8542  Hoàn Kiếm  2023-11-11T10:00:00
# 4           4  21.0285  105.8542  Hoàn Kiếm  2023-11-11T11:00:00
#
#          timestamp_utc  app_temp  azimuth  clouds  dewpt  ...  solar_rad  \
# 0  2023-11-11T00:00:00      26.9    113.8      25   24.8  ...        137
# 1  2023-11-11T01:00:00      27.1    121.2       0   25.0  ...        345
# 2  2023-11-11T02:00:00      30.5    131.3       0   24.8  ...        531
# 3  2023-11-11T03:00:00      35.1    145.4      62   25.2  ...        544
# 4  2023-11-11T04:00:00      36.4    164.6       0   23.9  ...        758
#
#    temp          ts   uv   vis  weather_code weather_description  wind_dir  \
# 0  25.8  1699660800  0.7   4.0           802    Scattered clouds       140
# 1  26.0  1699664400  2.0  10.0           800           Clear Sky        80
# 2  27.0  1699668000  3.1  10.0           800           Clear Sky       110
# 3  29.2  1699671600  5.1  10.0           803       Broken clouds       180
# 4  31.0  1699675200  5.9  16.0           800           Clear Sky       140
#
#    wind_gust_spd  wind_spd
# 0            3.6       2.0
# 1            4.8       2.1
# 2            5.6       3.1
# 3            6.0       2.0
# 4            6.4       3.1
#
# [5 rows x 30 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16776 entries, 0 to 16775
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           16776 non-null  int64
#  1   lat                  16776 non-null  float64
#  2   lon                  16776 non-null  float64
#  3   name                 16776 non-null  object
#  4   timestamp_local      16776 non-null  object
#  5   timestamp_utc        16776 non-null  object
#  6   app_temp             16776 non-null  float64
#  7   azimuth              16776 non-null  float64
#  8   clouds               16776 non-null  int64
#  9   dewpt                16776 non-null  float64
#  10  dhi                  16776 non-null  int64
#  11  elev_angle           16776 non-null  float64
#  12  ghi                  16776 non-null  int64
#  13  pod                  16776 non-null  object
#  14  precip               16776 non-null  float64
#  15  pres                 16776 non-null  int64
#  16  revision_status      16776 non-null  object
#  17  rh                   16776 non-null  int64
#  18  slp                  16776 non-null  int64
#  19  snow                 16776 non-null  int64
#  20  solar_rad            16776 non-null  int64
#  21  temp                 16776 non-null  float64
#  22  ts                   16776 non-null  int64
#  23  uv                   16776 non-null  float64
#  24  vis                  16770 non-null  float64
#  25  weather_code         16776 non-null  int64
#  26  weather_description  16776 non-null  object
#  27  wind_dir             16776 non-null  int64
#  28  wind_gust_spd        16776 non-null  float64
#  29  wind_spd             16776 non-null  float64
# dtypes: float64(12), int64(12), object(6)
# memory usage: 3.8+ MB

# %% [markdown]
# ## Feature explaination:
# 1.  Lat : Vĩ độ
# 2.  Lon: Kinh độ
# 3.  name: Địa điểm
# 4.  Timestamp_local: Thời gian tại địa điểm
# 5.  Timestamp_UTC: Thời gian theo UTC
# 6.  app_temp: nhiệt độ biểu kiến (HI, chỉ số nóng bức cảm nhận)
# 7. azimuth: Góc phương vị
# 8. clouds: Lượng mây phủ
# 9. dewpt: nhiệt độ hóa sương
# 10. dhi: lượng bức xạ mặt trời sau khi tán xạ trên 1 diện tích mặt đất
# 11. elev_angle: góc ngẩng (giữa đường chân trời và đường từ mắt đến mặt trời)
# 12. ghi: tổng lượng bức xạ của mặt trời lên phương ngang trên 1 diện tích mặt đất
# 13. pod: phần của ngày (ở đây được ghi chép với 2 giá trị d (ngày) và n (đêm))
# 14. precip: lượng mưa (giáng thủy)
# 15. pres: áp suất không khí
# 16. revision_status: tình trạng kiểm tra dự báo
# 17. rh: độ ẩm tương đối
# 18. slp: áp suất mực nước  biển
# 19. snow: lượng tuyết
# 20. solar_rad: lượng bức xạ mặt trời
# 21. temp: Nhiệt độ đo được
# 22. ts: timestamp UNIX
# 23. vis: tầm nhìn xa
# 24. uv: lượng uv
# 25. weather _code: mã thời tiết
# 26. weather_description: thời tiết
# 27. wind_dir: hướng gió
# 28. wind_gust: độ gió giật
# 29. wind_spd: tốc độ gió
#
#     Các đặc trưng địa lý: 1,2,
#     Các đặc trưng theo thời gian trong ngày: 6,7,10,11,12,13
#     Các đặc trưng khí tượng theo toàn thời gian: còn lại

# %%
data.describe()
# Out:
#          Unnamed: 0           lat         lon      app_temp       azimuth  \
# count  16776.000000  1.677600e+04  16776.0000  16776.000000  16776.000000
# mean    8387.500000  2.102850e+01    105.8542     27.794856    179.736451
# std     4842.958393  3.552820e-15      0.0000      8.209729     99.131275
# min        0.000000  2.102850e+01    105.8542      7.700000      0.000000
# 25%     4193.750000  2.102850e+01    105.8542     21.600000     87.300000
# 50%     8387.500000  2.102850e+01    105.8542     26.800000    180.000000
# 75%    12581.250000  2.102850e+01    105.8542     34.300000    272.425000
# max    16775.000000  2.102850e+01    105.8542     51.400000    360.000000
#
#              clouds         dewpt           dhi    elev_angle           ghi  \
# count  16776.000000  16776.000000  16776.000000  16776.000000  16776.000000
# mean      60.146102     20.352927     47.791786      0.721841    293.319742
# std       34.149302      5.927627     51.962808     44.525083    370.847189
# min        0.000000     -6.900000      0.000000    -88.600000      0.000000
# 25%       33.000000     16.800000      0.000000    -37.700000      0.000000
# 50%       66.000000     22.500000     16.000000      1.500000     11.000000
# 75%       91.000000     24.900000    107.000000     38.900000    641.250000
# max      100.000000     29.600000    128.000000     89.300000   1062.000000
#
#        ...     snow     solar_rad          temp            ts            uv  \
# count  ...  16776.0  16776.000000  16776.000000  1.677600e+04  16776.000000
# mean   ...      0.0    184.449332     25.129196  1.672054e+09      1.346692
# std    ...      0.0    268.540504      5.520399  1.743465e+07      1.957282
# min    ...      0.0      0.000000      7.700000  1.641859e+09      0.000000
# 25%    ...      0.0      0.000000     21.100000  1.656957e+09      0.000000
# 50%    ...      0.0     19.000000     26.000000  1.672054e+09      0.600000
# 75%    ...      0.0    290.250000     29.000000  1.687152e+09      2.100000
# max    ...      0.0   1061.000000     40.000000  1.702249e+09     12.100000
#
#                 vis  weather_code      wind_dir  wind_gust_spd     wind_spd
# count  16770.000000  16776.000000  16776.000000   16776.000000  16776.00000
# mean      11.985748    769.247437    155.853183       4.499022      2.25282
# std        3.409213     97.993508    107.725235       2.004091      1.15787
# min        0.000000    202.000000      0.000000       0.000000      0.00000
# 25%       10.000000    801.000000     80.000000       2.800000      1.50000
# 50%       10.000000    803.000000    140.000000       4.400000      2.00000
# 75%       16.000000    804.000000    240.000000       5.600000      3.00000
# max       16.000000    804.000000    360.000000      13.200000     10.80000
#
# [8 rows x 24 columns]

# %%
data.isnull().sum()
# Out:
# Unnamed: 0             0
# lat                    0
# lon                    0
# name                   0
# timestamp_local        0
# timestamp_utc          0
# app_temp               0
# azimuth                0
# clouds                 0
# dewpt                  0
# dhi                    0
# elev_angle             0
# ghi                    0
# pod                    0
# precip                 0
# pres                   0
# revision_status        0
# rh                     0
# slp                    0
# snow                   0
# solar_rad              0
# temp                   0
# ts                     0
# uv                     0
# vis                    6
# weather_code           0
# weather_description    0
# wind_dir               0
# wind_gust_spd          0
# wind_spd               0
# dtype: int64

# %%
data = data.drop(['Unnamed: 0','name','timestamp_utc', 'pod', 'revision_status'], axis = 1)

# %%
data = data.drop(['ts'], axis = 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16776 entries, 0 to 16775
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   lat                  16776 non-null  float64
#  1   lon                  16776 non-null  float64
#  2   timestamp_local      16776 non-null  object
#  3   app_temp             16776 non-null  float64
#  4   azimuth              16776 non-null  float64
#  5   clouds               16776 non-null  int64
#  6   dewpt                16776 non-null  float64
#  7   dhi                  16776 non-null  int64
#  8   elev_angle           16776 non-null  float64
#  9   ghi                  16776 non-null  int64
#  10  precip               16776 non-null  float64
#  11  pres                 16776 non-null  int64
#  12  rh                   16776 non-null  int64
#  13  slp                  16776 non-null  int64
#  14  snow                 16776 non-null  int64
#  15  solar_rad            16776 non-null  int64
#  16  temp                 16776 non-null  float64
#  17  uv                   16776 non-null  float64
#  18  vis                  16770 non-null  float64
#  19  weather_code         16776 non-null  int64
#  20  weather_description  16776 non-null  object
#  21  wind_dir             16776 non-null  int64
#  22  wind_gust_spd        16776 non-null  float64
#  23  wind_spd             16776 non-null  float64
# dtypes: float64(12), int64(10), object(2)
# memory usage: 3.1+ MB

# %%
import datetime as dt
from datetime import timedelta

# %%
#data["Date"]=pd.to_datetime(data['timestamp_local'])

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Phân tích về độ biến động của từng đặc trưng

# %%
features = ['app_temp', 'clouds', 'dewpt', 'precip', 'rh', 'temp']

fig, axs = plt.subplots(len(features), figsize=(10, 8), sharex=True)
fig.suptitle('Variation of Features Over Time')

for i, feature in enumerate(features):
    axs[i].plot(data['Date'], data[feature])
    axs[i].set_ylabel(feature)

plt.xlabel('Date')
plt.show()

# %%
features = ['azimuth','dhi','elev_angle','ghi','solar_rad','uv']

fig, axs = plt.subplots(len(features), figsize=(10, 8), sharex=True)
fig.suptitle('Variation of Features Over Time')

for i, feature in enumerate(features):
    axs[i].plot(data['Date'], data[feature])
    axs[i].set_ylabel(feature)

plt.xlabel('Date')
plt.show()

# %%
features = ['wind_dir','wind_gust_spd','wind_spd']

fig, axs = plt.subplots(len(features), figsize=(10, 8), sharex=True)
fig.suptitle('Variation of Features Over Time')

for i, feature in enumerate(features):
    axs[i].plot(data['Date'], data[feature])
    axs[i].set_ylabel(feature)

plt.xlabel('Date')
plt.show()

# %%
features = ['pres','slp']

fig, axs = plt.subplots(len(features), figsize=(10, 8), sharex=True)
fig.suptitle('Variation of Features Over Time')

for i, feature in enumerate(features):
    axs[i].plot(data['Date'], data[feature])
    axs[i].set_ylabel(feature)

plt.xlabel('Date')
plt.show()

# %% [markdown]
# Quan sát:
# * Những đặc trưng phụ thuộc nặng nề theo thời gian trong ngày, diễn ra theo chu kỳ trong ngày thì biểu đồ dầy, mượt và đối xứng. Những đặc trưng này không bị phụ thuộc vào các đặc điểm khí tượng khác.
# * Những đặc trưng khí tượng như app_temp, temp, dewpt, percip có xu hướng đối xứng. Đây là những đặc trưng diễn ra theo chu kỳ trong năm, do đó ít trơn mịn hơn.
# * Các đặc trưng còn lại dường như có độ đều theo các tháng.

# %%
#correlation
data_corr=data.drop(['timestamp_local','weather_code','weather_description'], axis = 1)
# assign data correlation matrix
relation = data_corr.corr()
# Increase the size of the heatmap
plt.figure(figsize=(15,10))
# Store heatmap object in a variable to easily access it when you want to include more features and you can set the annotation parameter to True to display the correlation values on the heatmap.
sns.heatmap(data=relation,annot=True,cmap='coolwarm')
# Give a title to the heatmap.
plt.title("Correlation of columns in the dataframe")
# # save the figure.
# plt.savefig('plot1.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Quan sát:
# * Các đặc trưng địa lý diễn ra theo ngày như quan sát trước đó:'azimuth','dhi','elev_angle','ghi','solar_rad','uv' thường có ít mối quan hệ đến các đặc trưng khác. Lưu ý nhóm chỉ số 'dhi','elev_angle','ghi','solar_rad','uv' liên quan với nhau bởi khái niệm lượng bức xạ nên phụ thuộc rõ rệt (tỉ lệ thuận)
# * Các cặp đặc trưng tỉ lệ nghịch với nhau lớn <-0,45:
#     -  app_temp & pres, app_temp & slp
#     -  dewpt & pres, dewpt & slp
#     -  pres & temp, slp & temp
#     -  rh & solar_rad, rh & uv
# * Các đặc trưng tỉ lệ thuận với nhau > 0,45:
#     -  app_temp &dewpt, app_temp &temp
#     -  dewpt &temp
#     -  dhi & elev_angle, dhi &ghi, dhi & solar_rad, dhi & uv,...
#     -  rh & dewpt
# * Từ đó, một số đặc trưng ít liên quan đến như 'clouds', 'precip', 'rh' trở nên thành những đặc trưng quan trọng.

# %%
#không có tuyết nên drop luôn cột này đi
data = data.drop(['snow'], axis = 1)

# %%
#Kinh độ và vĩ độ không đổi, cũng drop luôn
data = data.drop(['lat','lon'], axis = 1)

# %% [markdown]
# ### Nhãn và các đặc trưng

# %%
Weather= data['weather_description'].value_counts().reset_index()
Weather.columns=['Weather','Count']
Weather
# Out:
#                          Weather  Count
# 0                Overcast clouds   6577
# 1                  Broken clouds   3613
# 2               Scattered clouds   1791
# 3                      Clear Sky   1714
# 4                     Light rain   1444
# 5                     Few clouds   1097
# 6                            Fog    221
# 7                  Moderate rain    143
# 8                     Heavy rain     75
# 9   Thunderstorm with heavy rain     74
# 10                          Haze     27

# %%
print(27*100/(len(data)))
# Out:
# 0.1609442060085837

# %% [markdown]
# Chúng ta có tận 11 nhãn thời tiết, số lượng mẫu cho từng nhãn rất mất cân bằng (lớp thiểu số chiếm 0,16%<1%). Thời tiết ở nơi này đa phần liên quan về mây.

# %%
#data["Date"]=pd.to_datetime(data['timestamp_local'])

# %%
sns.set(rc={'figure.figsize':(8,4)})
plt.xticks(rotation=90)
sns.lineplot(x=Weather['Weather'],y=Weather['Count'],data=Weather)
plt.show()

# %%
#Weather vs Temp 
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
plt.title('Weather and Temperature')
sns.barplot(x=data['weather_description'],y=data['temp'])
# Out:
# <Axes: title={'center': 'Weather and Temperature'}, xlabel='weather_description', ylabel='temp'>

# %% [markdown]
# Đối với đặc trưng temp, độ lệch chuẩn trên toàn bộ mẫu của từng nhãn không lớn, riêng với nhãn Haze có độ lệch chuẩn lớn nhất, chứng tỏ các giá trị của temp sai khác nhiều với từng mẫu nhãn này.

# %%
#Weather vs cloud
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
plt.title('Weather and cloud')
sns.barplot(x=data['weather_description'],y=data['clouds'])
# Out:
# <Axes: title={'center': 'Weather and cloud'}, xlabel='weather_description', ylabel='clouds'>

# %% [markdown]
# Đặc trưng clouds cũng tương tự, nhưng đặc biệt với xu hướng lượng mây tăng dần thì số lượng mẫu cho từng nhãn liên quan về lượng mây cũng tăng.

# %%
#Weather vs DHI
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
plt.title('Weather and DHI')
sns.barplot(x=data['weather_description'],y=data['dhi'])
# Out:
# <Axes: title={'center': 'Weather and DHI'}, xlabel='weather_description', ylabel='dhi'>

# %% [markdown]
# Đối với đặc trưng DHI, độ lệch chuẩn trên các nhãn dữ liệu khá lớn, đặc biệt lớn với Haze, và các nhãn liên quan đến rain

# %%
#Weather vs pressure
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
plt.title('Weather and pressure')
sns.lineplot(x=data['weather_description'],y=data['pres'])
# Out:
# <Axes: title={'center': 'Weather and pressure'}, xlabel='weather_description', ylabel='pres'>

# %%
#Weather vs Relative humid
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
plt.title('Weather and Relative humid')
sns.lineplot(x=data['weather_description'],y=data['rh'])
# Out:
# <Axes: title={'center': 'Weather and Relative humid'}, xlabel='weather_description', ylabel='rh'>

# %% [markdown]
# Xu hướng: thời tiết từ mây đến mưa đến sương mù thì độ ẩm tăng theo.

# %%
# # Visualizing the temperature, observing if there's abnormal data
# plt.figure(figsize = (15, 5))
# fig = plt.plot(data['Date'], data['temp'])
# plt.grid();

# %% [markdown]
# Tóm lại:
# * Các đặc trưng ảnh hưởng theo ngày làm cho mỗi nhãn lớp có độ lệch chuẩn lớn, khó để nhận biết được sau này
# * Các đặc trưng quan trọng như clouds, rh, temp,... thể hiện cụ thể những nhãn lớp cụ thể hơn.

# %%
data = data.drop(['timestamp_local'], axis = 1)

# %% [markdown]
# ### Phân tích theo cặp đặc trưng

# %%
#Relation between Apparent Temperature & press Using Regression
#Resample according to month
df_column = ['Date','temp', 'pres']
df_monthly_mean = data[df_column].resample("MS", on='Date').mean() 
#MS-Month Starting
df_monthly_mean
# Out:
#                  temp         pres
# Date
# 2022-01-01  18.222133  1015.724346
# 2022-02-01  15.245387  1017.912202
# 2022-03-01  22.768548  1011.052419
# 2022-04-01  24.431944  1011.369444
# 2022-05-01  26.485887  1006.891129
# 2022-06-01  30.763750  1002.126389
# 2022-07-01  29.988172  1003.231183
# 2022-08-01  29.341667  1003.737903
# 2022-09-01  28.438889  1007.831944
# 2022-10-01  25.472715  1013.881720
# 2022-11-01  25.223194  1012.572222
# 2022-12-01  17.111022  1019.213710
# 2023-01-01  17.611559  1018.772849
# 2023-02-01  20.321726  1015.906250
# 2023-03-01  22.277823  1013.768817
# 2023-04-01  25.053611  1007.975000
# 2023-05-01  28.815726  1005.810484
# 2023-06-01  29.730139  1002.777778
# 2023-07-01  30.683199  1002.767473
# 2023-08-01  29.049462  1002.108871
# 2023-09-01  28.456667  1006.537500
# 2023-10-01  27.196505  1012.987903
# 2023-11-01  23.639028  1016.651389
# 2023-12-01  20.316599  1016.040486

# %%
# calling regplot function and assign it with our data and plot labels and color parameter.
sns.regplot(data=df_monthly_mean, x="temp", y="pres", color="r")
# Give a title to the plot
plt.title("Relation between  Temperature (C) and pressure")
# save the figure
plt.savefig('plot2.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Càng lên cao, áp suất KK càng giảm, nhiệt độ cảm nhận được tăng theo. "When temparature increases the molecule will get energise moves apart from each other and the attraction between molecule will decreases and eventually pressure will decreases"

# %%
#Sự thay đổi hàng tháng của nhiệt độ và áp suất
plt.figure(figsize=(15,7))
sns.lineplot(data= df_monthly_mean)
plt.xlabel('Month')
plt.title('Variation of  Temprature and Pressure with Time')
plt.savefig('plot3.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df_column_temp_rh = ['Date','temp', 'rh']
df_monthly_mean_temp_rh = data[df_column_temp_rh].resample("MS", on='Date').mean()

# %%
#Sự thay đổi hàng tháng của nhiệt độ và độ ẩm
plt.figure(figsize=(15,7))
sns.lineplot(data= df_monthly_mean_temp_rh)
plt.xlabel('Month')
plt.title('Variation of Apparent Temprature and HUmidity with Time')
plt.savefig('plot3.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df_column_ghi_solar_rad = ['Date','ghi', 'solar_rad']
df_monthly_mean_ghi_solar_rad= data[df_column_ghi_solar_rad].resample("MS", on='Date').mean() 
#Sự thay đổi hàng tháng của năng lượng mặt trời và lượng GHI
plt.figure(figsize=(15,7))
sns.lineplot(data= df_monthly_mean_ghi_solar_rad)
plt.xlabel('Month')
plt.title('Variation of GHI and solar radition with Time')
plt.savefig('plot3.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
sns.regplot(data=df_monthly_mean_ghi_solar_rad, x="ghi", y="solar_rad", color="r")
# Give a title to the plot
plt.title("Relation between  GHI and solar rad")
# save the figure
plt.savefig('plot2.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Solar rad dường như có vẻ bị thất thoát thành những dạng tia khác. 2 đặc trưng này tỉ lệ thuận với nhau.

# %%
#Wind Features
fig, ax = plt.subplots(1,2, figsize=(17, 5))
sns.distplot(data['wind_gust_spd'], ax=ax[0])
sns.distplot(data['wind_spd'], ax=ax[1])
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_892\4128914830.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['wind_gust_spd'], ax=ax[0])
# C:\Users\HP\AppData\Local\Temp\ipykernel_892\4128914830.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['wind_spd'], ax=ax[1])

# %% [markdown]
# Biểu đồ thể hiện bản chất khác nhau giữa tốc độ gió giật (diễn ra trong vài giây) so với tốc độ gió trung bình bình thường (xét trong vài phút). Mật độ giá trị tốc độ giá trị được băm nhỏ hơn và tương đối trơn so với tốc độ gió bình thường.

# %%
# pip install plotly

# %%
# import plotly.express as px

# %%
# def angle_range(st, ed, x):
#     if st < ed: ed += 360
#     return st <= x.values < ed

# def wind_news(df):
#     df = df[df['wind_dir'] > 0]
#     df['wind_dir'][ df['wind_dir'] < 11.25 ] = df['wind_dir'][ df['wind_dir'] < 11.25 ].apply(lambda x : x+360)
    
#     wind_df = pd.DataFrame(columns=['direction', 'speed', 'frequency'])
#     angle = [ (i * 22.5 - 11.25 + 360) % 360.0 for i in range(16) ]
#     direction = ['N', 'NNE', 'NE', 'ENE', 'E', 'ESE', 'SE', 'SSE', 'S', 'SSW', 'SW', 'WSW', 'W', 'WMW', 'NW', 'NNW']
#     speed = [i*2.5 for i in range(1, 9)]
#     tot = 0
#     for ang, d  in zip(angle, direction):
#         for s in speed:
#             cnt = df[(ang <= df['wind_dir'] ) & ( df['wind_dir'] < ang+22.5 )&  (s-2.5 <= df['wind_spd']) & (df['wind_spd'] < s) ].shape[0]
#             tot += cnt
#             # Create a DataFrame from the dictionary
#             data_to_append = {'direction': [d], 'speed': [s], 'frequency': [cnt]}
#             new_data = pd.DataFrame(data_to_append)
            
#             # Concatenate the new DataFrame with the existing 'wind_df'
#             wind_df = pd.concat([wind_df, new_data], ignore_index=True)
#     return wind_df

# %%
# def wind_direction_plot(df, title):
#     wind = wind_news(df)
#     fig = px.bar_polar(wind, r="frequency", theta="direction",
#                        color="speed", template="plotly_dark",
#                        color_discrete_sequence= px.colors.sequential.Plasma[-2::-1])
#     fig.update_layout(title_text='HK'.format(title))
#     fig.show()

# %%
# wind_direction_plot(ata, str(0))

# %% [markdown]
# ### Kiểm định giả thiết

# %%
#Liệu áp suất mực nước biển thay đổi có ảnh hưởng đến thời tiết hay không?
## Count by slp ##
plt.figure(figsize=(15,10))
data.slp.value_counts().sort_index().plot(kind='bar')
plt.title("Count value by slp")
plt.show()

# %%
#Kiểm tra có cùng phân phối hay không
slp_999 = data[data['slp'] == 999]['weather_code']
slp_1005 = data[data['slp'] == 1005]['weather_code']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16776 entries, 0 to 16775
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   app_temp             16776 non-null  float64
#  1   azimuth              16776 non-null  float64
#  2   clouds               16776 non-null  int64
#  3   dewpt                16776 non-null  float64
#  4   dhi                  16776 non-null  int64
#  5   elev_angle           16776 non-null  float64
#  6   ghi                  16776 non-null  int64
#  7   precip               16776 non-null  float64
#  8   pres                 16776 non-null  int64
#  9   rh                   16776 non-null  int64
#  10  slp                  16776 non-null  int64
#  11  solar_rad            16776 non-null  int64
#  12  temp                 16776 non-null  float64
#  13  uv                   16776 non-null  float64
#  14  vis                  16770 non-null  float64
#  15  weather_code         16776 non-null  int64
#  16  weather_description  16776 non-null  object
#  17  wind_dir             16776 non-null  int64
#  18  wind_gust_spd        16776 non-null  float64
#  19  wind_spd             16776 non-null  float64
#  20  Date                 16776 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(10), int64(9), object(1)
# memory usage: 2.7+ MB

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in d:\miniconda\envs\prjds\lib\site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in d:\miniconda\envs\prjds\lib\site-packages (from scipy) (1.24.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
### Null hypothesis: dữ liệu tuân theo phân phối chuẩn ###
### Nếu pValue < 0.05 ==> phản bác null hypothesis ###
from scipy import stats
slp_999_dist = stats.shapiro(slp_999)
slp_1005_dist = stats.shapiro(slp_1005)

print('pvalue for 999 distribution: ', slp_999_dist[1])
print('pvalue for 1005 distribution: ', slp_1005_dist[1])
# Out:
# pvalue for 1014 distribution:  4.326834025884174e-25
# pvalue for 1005 distribution:  2.802596928649634e-45

# %% [markdown]
# Rõ ràng, phân phôi của 2 giá trị này khác phân phối chuẩn nên không thể kết luận được slp ảnh hưởng đến thời tiết.

# %%
#Lưu ý, các giá trị thời tiết sử dụng code của chúng (thay vì dạng string)
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5))

ax[0].hist(x=slp_999, bins=15, color = 'g')
ax[0].title.set_text('Weather / 999pres Distribution')

ax[1].hist(x=slp_1005, bins=15, color = 'grey')
ax[1].title.set_text('Weather / 1005pres Distribution')

plt.show()

# %% [markdown]
# ## Feature selection

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
df_column = ['app_temp','azimuth','clouds', 'dewpt','dhi','elev_angle','ghi','precip','pres', 'rh','slp','solar_rad','temp','uv','wind_dir','wind_gust_spd','wind_spd']
X = data[df_column]  #independent columns
y = data['weather_code']    #target column i.e price range
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(17).plot(kind='barh')
plt.show()
# Out:
# [0.02636323 0.01999711 0.53981953 0.0245127  0.01408876 0.02028717
#  0.01432529 0.11994693 0.02262844 0.03386863 0.02240857 0.03754078
#  0.02605356 0.0125564  0.02618495 0.01854559 0.02087236]
